# %%
menu={
  "type": "carousel",
  "contents": [
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/mVGtSbx.png",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        },
        "contents": [
          {
            "type": "text",
            "text": "臭LV.1",
            "weight": "bold",
            "size": "xl",
            "contents": []
          },
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": [
              {
                "type": "box",
                "layout": "baseline",
                "contents": [
                  {
                    "type": "text",
                    "text": "$250",
                    "weight": "bold",
                    "margin": "sm",
                    "contents": []
                  }
                ]
              }
            ]
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "詳情",
              "uri": "https://www.youtube.com/watch?v=xvFZjo5PgG0&ab_channel=Duran"
            },
            "color": "#905C44",
            "style": "primary"
          },
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "點一下+1",
              "data": "臭LV.1"
            },
            "color": "#CBBF1FAA"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/4KaCjOe.png",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        },
        "contents": [
          {
            "type": "text",
            "text": "臭LV.2",
            "weight": "bold",
            "size": "xl",
            "contents": []
          },
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": [
              {
                "type": "box",
                "layout": "baseline",
                "contents": [
                  {
                    "type": "text",
                    "text": "$350",
                    "weight": "bold",
                    "margin": "sm",
                    "contents": []
                  }
                ]
              }
            ]
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "詳情",
              "uri": "https://www.youtube.com/watch?v=xvFZjo5PgG0&ab_channel=Duran"
            },
            "color": "#905C44",
            "style": "primary"
          },
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "點一下+1",
              "data": "臭LV.2"
            },
            "color": "#CBBF1FAA"
          }
        ]
      }
    },
    {
      "type": "bubble",
      "hero": {
        "type": "image",
        "url": "https://i.imgur.com/9xYJdQ4.jpg",
        "size": "full",
        "aspectRatio": "20:13",
        "aspectMode": "cover",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        }
      },
      "body": {
        "type": "box",
        "layout": "vertical",
        "spacing": "md",
        "action": {
          "type": "uri",
          "label": "Action",
          "uri": "https://linecorp.com"
        },
        "contents": [
          {
            "type": "text",
            "text": "臭LV.3",
            "weight": "bold",
            "size": "xl",
            "contents": []
          },
          {
            "type": "box",
            "layout": "vertical",
            "spacing": "sm",
            "contents": [
              {
                "type": "box",
                "layout": "baseline",
                "contents": [
                  {
                    "type": "text",
                    "text": "$450",
                    "weight": "bold",
                    "margin": "sm",
                    "contents": []
                  }
                ]
              }
            ]
          }
        ]
      },
      "footer": {
        "type": "box",
        "layout": "vertical",
        "contents": [
          {
            "type": "button",
            "action": {
              "type": "uri",
              "label": "詳情",
              "uri": "https://www.youtube.com/watch?v=xvFZjo5PgG0&ab_channel=Duran"
            },
            "color": "#905C44",
            "style": "primary"
          },
          {
            "type": "button",
            "action": {
              "type": "postback",
              "label": "點一下+1",
              "data": "臭LV.3"
            },
            "color": "#CBBF1FAA"
          }
        ]
      }
    }
  ]
}

# %%
choise={
  "type": "bubble",
  "direction": "ltr",
  "header": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": "結帳",
          "text": "結帳"
        },
        "color": "#F99696FF"
      },
      {
        "type": "button",
        "action": {
          "type": "message",
          "label": "重新選擇",
          "text": "重新選擇"
        },
        "color": "#FFD285FF"
      }
    ]
  }
}

# %%
#點餐
from flask import Flask, request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi, WebhookHandler
from linebot.models import FlexSendMessage, TextSendMessage
import json
token="Dxmj+v1ZFfgRUmLt5qp6PSyJ0r9vIt/g6jmT8yTWaBVNoKWoXbxUQU2YjmYd8594HefXbiEoYRGckUVbIHKBMCxCYP+Y3FvkNU75k/SAR35GpvhGszmELLCAS18ZL401wJxdbE9Cp65ewo8RtWQuGgdB04t89/1O/w1cDnyilFU="
app = Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot = LineBotApi(token)
user={}
@app.route("/", methods=['POST'])
def verify():
    data = request.get_json()
    print(data)
    #給Webhook驗證使用
    if len(data['events'])==0:
        print("webhook驗證通知")
        pass
    elif data['events'][0]['type']=="message":
        TEXT=data['events'][0]['message']['text']
        UID=data['events'][0]['source']['userId']
        RPTK=data['events'][0]['replyToken']
        if UID in user:#使用者已有登錄
            if TEXT=="結帳":
                user[UID]["總金額"]=user[UID]['臭LV.1']*250+user[UID]['臭LV.2']*350+user[UID]['臭LV.3']*450
                line_bot.reply_message(RPTK,TextSendMessage(text="總計%d元"%(user[UID]["總金額"])))
                user[UID]={'臭LV.1':0,'臭LV.2':0,'臭LV.3':0,'總金額':0}
            elif TEXT=="重新選擇":
                user[UID]={'臭LV.1':0,'臭LV.2':0,'臭LV.3':0,'總金額':0}
            else:
                line_bot.reply_message(RPTK,[FlexSendMessage(alt_text="點餐囉,記得看詳情", contents=menu),FlexSendMessage(alt_text="點餐囉,記得看詳情", contents=choise)])
        else:#使用者未登錄過
            user[UID]={'臭LV.1':0,'臭LV.2':0,'臭LV.3':0,'總金額':0}
            line_bot.reply_message(RPTK,[FlexSendMessage(alt_text="點餐囉,記得看詳情", contents=menu),FlexSendMessage(alt_text="點餐囉,記得看詳情", contents=choise)])
    else :
        DATA=data['events'][0]['postback']['data']
        UID=data['events'][0]['source']['userId']
        user[UID][DATA]+=1
    return 'OK',200    
if __name__ == "__main__":
    app.run(port=1300)
