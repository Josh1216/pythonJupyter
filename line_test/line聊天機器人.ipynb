# %%
from flask import Flask, request
#https://github.com/line/line-bot-sdk-python
from linebot import LineBotApi, WebhookHandler
from linebot.models import FlexSendMessage, TextSendMessage
import json
token="Dxmj+v1ZFfgRUmLt5qp6PSyJ0r9vIt/g6jmT8yTWaBVNoKWoXbxUQU2YjmYd8594HefXbiEoYRGckUVbIHKBMCxCYP+Y3FvkNU75k/SAR35GpvhGszmELLCAS18ZL401wJxdbE9Cp65ewo8RtWQuGgdB04t89/1O/w1cDnyilFU="
app = Flask(__name__)
# LINE 聊天機器人的基本資料
line_bot = LineBotApi(token)
@app.route("/", methods=['POST'])
def verify():
    data = request.get_json()
    print(data)
    #給Webhook驗證使用
    if len(data['events'])==0:
        print("webhook驗證通知")
        pass
    else:
        TEXT=data['events'][0]['message']['text']
        UID=data['events'][0]['source']['userId']
        RPTK=data['events'][0]['replyToken']
        line_bot.reply_message(RPTK,[FlexSendMessage(alt_text="123",contents={
  "type": "bubble",
  "direction": "ltr",
  "header": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "ㄍㄚˇ挖電電",
        "align": "center",
        "contents": []
      }
    ]
  },
  "hero": {
    "type": "image",
    "url": "https://i.imgur.com/bjx1DVJ.jpg",
    "size": "full",
    "aspectRatio": "1.51:1",
    "aspectMode": "fit"
  },
  "body": {
    "type": "box",
    "layout": "vertical",
    "contents": [
      {
        "type": "text",
        "text": "狗妹",
        "align": "center",
        "contents": []
      }
    ]
  },
  "footer": {
    "type": "box",
    "layout": "horizontal",
    "contents": [
      {
        "type": "button",
        "action": {
          "type": "uri",
          "label": "OVER MY DEAD BODY",
          "uri": "https://www.youtube.com/watch?v=xvFZjo5PgG0&ab_channel=Duran"
        }
      }
    ]
  }
})])
    return 'OK',200    
if __name__ == "__main__":
    app.run(port=1300)
