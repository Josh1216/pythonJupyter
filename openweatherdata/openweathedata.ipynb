# %%
import requests
from bs4 import BeautifulSoup
import json
from time import sleep
res=requests.get('https://opendata.cwb.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=CWB-7AF48CE0-7849-43EB-A1EF-BD21234639D8&locationName=臺中市')
resText = json.loads(res.text)
weatherDetailed = resText['records']['location'][0]['weatherElement']
count1=0
count2=0
while count1 <=4:
    for count2 in range(0,3):
        print(weatherDetailed[count1]['time'][count2]['startTime'])
        print(weatherDetailed[count1]['time'][count2]['endTime'])
        print(weatherDetailed[count1]['time'][count2]['parameter']['parameterName'])
        for i in weatherDetailed[count1]['time'][count2]['parameter']:
            print(weatherDetailed[count1]['time'][count2]['parameter'][i])
        count2+=1
    print("====NEXT====")
    
    count1+=1
    
#天氣狀況
# print(resText['records']['location'][0]['weatherElement'][0]['time'][0])
# print(resText['records']['location'][0]['weatherElement'][0]['time'][1])
# print(resText['records']['location'][0]['weatherElement'][0]['time'][2])

#降雨機率
# print(resText['records']['location'][0]['weatherElement'][1]['time'][0])
# print(resText['records']['location'][0]['weatherElement'][1]['time'][1])
# print(resText['records']['location'][0]['weatherElement'][1]['time'][2])

#溫度
# print(resText['records']['location'][0]['weatherElement'][2]['time'][0])
# print(resText['records']['location'][0]['weatherElement'][2]['time'][1])
# print(resText['records']['location'][0]['weatherElement'][2]['time'][2])

#舒適指數
# print(resText['records']['location'][0]['weatherElement'][3]['time'][0])
# print(resText['records']['location'][0]['weatherElement'][3]['time'][1])
# print(resText['records']['location'][0]['weatherElement'][3]['time'][2])


#溫度
# print(resText['records']['location'][0]['weatherElement'][4]['time'][0])
# print(resText['records']['location'][0]['weatherElement'][4]['time'][1])
# print(resText['records']['location'][0]['weatherElement'][4]['time'][2])
# Out:
# 2023-08-22 18:00:00
# 2023-08-23 06:00:00
# 多雲時晴
# {'parameterName': '多雲時晴', 'parameterValue': '3'}
# 2023-08-23 06:00:00
# 2023-08-23 18:00:00
# 多雲時陰
# {'parameterName': '多雲時陰', 'parameterValue': '5'}
# 2023-08-23 18:00:00
# 2023-08-24 06:00:00
# 晴時多雲
# {'parameterName': '晴時多雲', 'parameterValue': '2'}
# ====NEXT====
# 2023-08-22 18:00:00
# 2023-08-23 06:00:00
# 20
# {'parameterName': '20', 'parameterUnit': '百分比'}
# 2023-08-23 06:00:00
# 2023-08-23 18:00:00
# 20
# {'parameterName': '20', 'parameterUnit': '百分比'}
# 2023-08-23 18:00:00
# 2023-08-24 06:00:00
# 20
# {'parameterName': '20', 'parameterUnit': '百分比'}
# ====NEXT====
# 2023-08-22 18:00:00
# 2023-08-23 06:00:00
# 28
# {'parameterName': '28', 'parameterUnit': 'C'}
# 2023-08-23 06:00:00
# 2023-08-23 18:00:00
# 28
# {'parameterName': '28', 'parameterUnit': 'C'}
# 2023-08-23 18:00:00
# 2023-08-24 06:00:00
# 27
# {'parameterName': '27', 'parameterUnit': 'C'}
# ====NEXT====
# 2023-08-22 18:00:00
# 2023-08-23 06:00:00
# 舒適至悶熱
# ...

# %%
'https://opendata.cwb.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization=CWB-7AF48CE0-7849-43EB-A1EF-BD21234639D8&locationName=%E8%87%BA%E4%B8%AD%E5%B8%82'
